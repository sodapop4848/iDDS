# %% [markdown]
# <a href="https://colab.research.google.com/github/sodapop4848/iDDS/blob/dev/Ho2_HF_API_calls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install transformers requests

import requests
import json
import os
from transformers import AutoTokenizer

# %%
from google.colab import userdata
HF_API_KEY = userdata.get('HF_TOKEN')
API_URL = "https://api-inference.huggingface.co/models/mistralai/Mistral-7B-Instruct-v0.3"
HEADERS = {"Authorization": f"Bearer {HF_API_KEY}"}
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e0a129b57905> in <cell line: 0>()
#       1 from google.colab import userdata
# ----> 2 HF_API_KEY = userdata.get('HF_TOKEN')
#       3 API_URL = "https://api-inference.huggingface.co/models/mistralai/Mistral-7B-Instruct-v0.3"
#       4 HEADERS = {"Authorization": f"Bearer {HF_API_KEY}"}
#
# /usr/local/lib/python3.11/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret HF_TOKEN does not exist.

# %%
def query_huggingface(payload):
    response = requests.post(API_URL, headers=HEADERS, json=payload)
    return response.json()

# %%
# Well-Formatted Resume (Professional & Readable)

well_formatted_resume = """
John Doe
New York, NY | johndoe@email.com | (123) 456-7890 | LinkedIn: linkedin.com/in/johndoe

--------------------------------------------------------
PROFESSIONAL SUMMARY
--------------------------------------------------------
Experienced Data Scientist with 5+ years in machine learning, NLP, and AI model development.
Passionate about solving real-world problems using data-driven insights.

--------------------------------------------------------
EXPERIENCE
--------------------------------------------------------
Data Scientist | ABC Tech Solutions | Jan 2020 – Present
- Developed an NLP-based resume parser that improved hiring efficiency by 30%.
- Built a recommendation engine that increased user engagement by 20%.
- Optimized machine learning pipelines, reducing model training time by 40%.

Machine Learning Engineer | XYZ Analytics | Jul 2017 – Dec 2019
- Designed and deployed predictive models for customer churn analysis.
- Worked on time-series forecasting to improve sales predictions by 15%.

--------------------------------------------------------
EDUCATION
--------------------------------------------------------
Master of Science in Data Science | University of California, Berkeley | 2017
Bachelor of Science in Computer Science | NYU | 2015

--------------------------------------------------------
SKILLS
--------------------------------------------------------
- Programming: Python, R, SQL
- ML Frameworks: TensorFlow, PyTorch, Scikit-Learn
- Data Processing: Pandas, NumPy, Spark
- NLP: Transformers, NLTK, SpaCy
- Cloud: AWS, GCP, Azure

--------------------------------------------------------
CERTIFICATIONS
--------------------------------------------------------
- AWS Certified Machine Learning – Specialty
- Google Professional Data Engineer

--------------------------------------------------------
PROJECTS
--------------------------------------------------------
- Developed an AI chatbot for customer support using GPT-3.
- Built a resume parser using Named Entity Recognition (NER).
"""

# poorly formatted resume

poorly_formatted_resume = """
John Doe,New York,NY johndoe@email.com,1234567890 LinkedIn linkedin.com/in/johndoe
PROFESSIONALSUMMARY: Experienced Data Scientist 5+ years,ML,NLP,AI model development solving problems w data

EXPERIENCE
Data Scientist @ ABC Tech Solutions Jan 2020 – Present
* NLP-based resume parser,30% hiring efficiency.
* Recommendation engine,user engagement ↑ 20%
* Optimized ML pipelines;training ↓ 40%

Machine Learning Engineer,XYZ Analytics,Jul 2017 – Dec 2019
- Designed/deployed predictive models 4 customer churn
- Time-series forecasting,↑sales 15%

EDUCATION:
MSc Data Science @ UC Berkeley, 2017
BSc CS NYU 2015

Skills: Python,R,SQL,TensorFlow,PyTorch,Scikit-Learn,Pandas,NumPy,Azure,Spark,NLP, GCP

Certifications- AWS ML Specialty,Google Data Engineer

Projects:
- AI chatbot 4 customer support GPT-3
- Resume Parser w/ NER
"""

# %%
resume_1 = "John Doe is a Data Scientist with 5 years of experience in Python, Machine Learning, and Deep Learning."
resume_2 = "Jane Smith has a background in Software Development, specializing in Java, Cloud Computing, and DevOps."
resume_3 = "Mike Johnson is a recent graduate with a passion for Artificial Intelligence and Data Analysis."

resumes = [resume_1, resume_2, resume_3]
# resumes = [well_formatted_resume, poorly_formatted_resume]

for i, resume in enumerate(resumes, 1):
    # print(f"Resume {i}: {resume}\n")
    response = query_huggingface({"inputs": resume})
    print(f"Model Feedback: {response[0]['generated_text']}\n")
# Out:
# Model Feedback: John Doe is a Data Scientist with 5 years of experience in Python, Machine Learning, and Deep Learning. In his current role, he is working on a project to automate the analysis of satellite imagery to detect deforestation in the Amazon Rainforest. His responsibilities include:
#
# 1. Developing algorithms for object detection, segmentation, and anomaly detection on satellite imagery.
# 2. Training machine learning models using large datasets to increase accuracy and efficiency.
# 3. Collaborating with a team of scientists and researchers to integrate the model into a larger ecosystem of data processing and analysis tools.
# 4. Maintaining and updating the model as new data becomes available.
# 5. Analyzing the results of the model to identify trends and patterns in deforestation activity.
#
# John Doe has a strong background in computer science and mathematics, with a Bachelor's degree from XYZ University. He has also completed a Master's degree in Data Science from ABC University. In addition to his technical skills, John is known for his strong problem-solving abilities, attention to detail, and ability to communicate complex concepts clearly to both technical and non-technical audiences.
#
# John's work on the deforestation project has been well-received by the scientific community, and he has presented his findings at several conferences. He is passionate about using technology to help protect the environment and is committed to continuing to learn and improve in his field.
#
# In his free time, John enjoys hiking, photography, and playing the guitar. He is also an avid reader, with a particular interest in science fiction and fantasy. John is always looking for opportunities to learn and grow, and is excited about the future of data science and its potential to make a positive impact on the world.
#
# Model Feedback: Jane Smith has a background in Software Development, specializing in Java, Cloud Computing, and DevOps. She also has a strong interest in open-source software and collaborating with others to improve software development practices. Jane is a well-regarded speaker and enjoys sharing her knowledge at conferences and meetups. In her free time, Jane enjoys hiking and playing music.
#
# [Jane Smith](mailto:jsmith@example.com)
# Java Developer, DevOps specialist, and open-source enthusiast | [GitHub](https://github.com/janesmith) | [LinkedIn](https://www.linkedin.com/in/janesmith)
#
# ## Professional Summary
#
# Experienced Java Developer and DevOps specialist with a passion for open-source software and collaborating with others to improve software development practices. Proficient in Java, Cloud Computing, and DevOps tools such as Jenkins, Docker, and Kubernetes. Strong problem-solving skills and the ability to learn new technologies quickly. Skilled at writing secure, maintainable, and scalable code. Committed to continuous learning and technical excellence.
#
# ## Skills
#
# - Java (Internet, Enterprise, Spring, Hibernate, JUnit)
# - Cloud Computing (AWS, Azure, Google Cloud)
# - DevOps (Jenkins, Docker, Kubernetes, containerization, continuous integration, continuous delivery, version control)
# - Open-source software (contributing to projects, creating new projects, sharing knowledge)
# - Agile methodologies (Scrum, Kanban)
# - Database (MySQL, PostgreSQL, SQL Server)
# - Linux (Ubuntu, CentOS)
# - Competent in scripting languages such as shell scripting and Bash
#
# ## Work Experience
#
# ### Java Developer (2016 - present)
#
# *Company X*, City, State
#
# - Develop and maintain Java applications using Internet/Enterprise Java technologies such as Spring, Hibernate, JUnit, Java 8, and Java 11.
# - Collaborate with the team to design, develop, and deploy features and fixes for our customer-facing web applications.
# - Write clean, secure, and maintainable code. Follow best practices for coding standards, design patterns, and test-driven development.
# - Work with the DevOps team to implement continuous integration, continuous delivery, and infrastructure automation using Jenkins, Docker, Kubernetes, and containerization.
# - Maintain and improve the performance of existing applications by optimizing code and identifying bottlenecks.
# - Contribute to open-source projects and create new projects as needed to share knowledge and improve the open-source software community.
#
# ### Junior Java Developer (2014 - 2016)
#
# *Company Y*, City, State
#
# - Work on technical tasks under the guidance of senior Java developers.
# - Develop Java applications using Internet/Enterprise Java technologies such as Spring, Hibernate, JUnit, Java 8, and Java 11.
# - Learn best practices for coding standards, design patterns, and test-driven development.
# - Contribute to the development of customer-facing web applications.
# - Participate in Agile development processes such as daily stand-ups, sprint planning meetings, and retrospectives.
# - Collaborate with the DevOps team to implement continuous integration, continuous delivery, and infrastructure automation.
# - Contribute to open-source projects and create new projects as needed to share knowledge and improve the open-source software community.
#
# ## Projects
#
# ### Java Microservices Framework (2016 - present)
#
# Open-source project on GitHub to create a lightweight and modular Java microservices framework. The project includes features such as automatic configuration, security, logging, and monitoring.
#
# - Designed and implemented the core components of the framework.
# - Developed and maintained the project documentation, including usage examples and tests.
# - Collaborated with other open-source contributors to improve the framework and add new features.
# - Presented the project at conferences and meetups to share knowledge and connect with other developers.
#
# ### Containerization of Java Applications (2017)
#
# Open-source project on GitHub to containerize Java applications using Docker and Kubernetes.
#
# - Designed and implemented a Dockerfile for a Java application.
# - Created a Kubernetes deployment and service to deploy the containerized application to a production environment.
# - Tested the containerized application in various environments and optimized performance.
# - Documented the process and shared it with the open-source community.
#
# ## Education
#
# ### Bachelor of Science in Computer Science (2011-2014)
#
# *University Z*, City, State
#
# ## Certifications
#
# ### Certified Java Developer (2016)
#
# Oracle Corporation
#
# ### AWS Certified DevOps Engineer - Professional (2018)
#
# Amazon Web Services
#
# ## Languages
#
# - English: Fluent
# - French: Basic Fluency
#
# ## Interests
#
# - Hiking
# - Playing music
# - Attending conferences and meetups
#
# ## References
#
# available upon request
#
# Model Feedback: Mike Johnson is a recent graduate with a passion for Artificial Intelligence and Data Analysis. He has a Bachelor’s in Computer Engineering from Singapore institute of Technology and is currently predicting the future (or optimizing given data) by building cool models with Python and R. His Logical Reasoning test score was 96th percentile, and he cracked the 101st percentile in Quantitative Reasoning!
#
# 1. What sparked your initial interest in AI?
#
# AI has always been a fascinating topic to me, ever since I read “The Lemark Inheritance” in middle school. While I didn’t know the acronym back then, I was hooked on the idea of a computer making decisions and predicting the future (or optimizing given data). I started taking small steps towards AI by learning about Logic programming and Bayesian Networks in high school.
#
# 2. You cracked the 101st percentile in Quantitative Reasoning. What tips and study methods do you have for others going through the same test?
#
# The key to Quantitative Reasoning is practicing -BUT- getting the right kind of practice. I’d recommend buying the Prep-test Companion Book by Princeton Review and following the practice plan outlined in it. Personally, I found it to be the most effective form of practice as it helped me familiarize myself with the concepts and question formats. More importantly, Princeton Review has validated their study plans via research, so you know that the way they structure their practice material is the best approach towards cracking that 101st percentile.
#
# 3. Did your background in Computer Engineering prepare you for a career in AI? What aspects from your degree have been useful and which have been less useful?
#
# Yes and no. My Computer Engineering background gave me a great foundation of the computer science basics and algorithms. It’s essential for any computer science discipline and knowing them provided a head start as I cracked down the learning of AI.
#
# However, my Computer Engineering degree didn’t cover the machine learning or deep learning topics, which are the real meat of AI. These were covered in other online courses in a more intuitive and layman’s language. So while actual AI-specific learning wasn’t part of my degree, my fundamentals sure were useful to grasp the advanced concepts.
#
# 4. How would you recommend someone to become an expert in AI? For someone like me going through college, what are some specific courses and topics to take?
#
# I’d recommend enrolling in online courses focusing on machine learning and deep learning. My two favorites are Andrew Ng’s Machine Learning course offered by Coursera – it’s free and is a 10-week, fully-fledged course that covers various machine learning algorithms and intuitive concepts. To learn deep learning, check out Ian Goodfellow’s course on deep learning by Francois Chollet (creator of Keras).
#
# For someone in college:
#
# – If your program covers programming, learn to code in Python. Python is currently the dominant language used in AI (and data analysis, which I believe all AI folks should be interested in).
# – Mathematically-inclined students can explore Calculus (multivariable) and Linear Algebra. They’re extremely useful in understanding the underlying principles of machine learning and deep learning algorithms.
# – As for specific courses, anything that involves Statistics, Optimization, Information Theory and Probability would be extremely useful. You can imagine these subjects as pre-requisites to diving into machine and deep learning! For the best results, start with basic statistics and gradually attempt the more advanced topics.

# %%
custom_instruction = "Analyze the resume and provide feedback on formatting."

for i, resume in enumerate(resumes, 1):
    response = query_huggingface({"inputs": f"{custom_instruction} {resume}"})
    print(f"Custom Instruction Feedback: {response[0]['generated_text']}\n")
# Out:
# Custom Instruction Feedback: Analyze the resume and provide feedback on formatting. John Doe is a Data Scientist with 5 years of experience in Python, Machine Learning, and Deep Learning. He has worked on various projects, including Predictive Modeling, Natural Language Processing, and Computer Vision.
#
# Overall, the formatting of John Doe's resume is well-organized and easy to read. The use of bullet points under each job title makes it easy to quickly scan his experience and understand his responsibilities and achievements. However, there are a few areas that could be improved to make the resume even stronger:
#
# 1. Use consistent formatting for headings: The resume uses a mix of uppercase and lowercase letters for headings, which can be visually distracting. To make the resume more professional and consistent, use all uppercase letters for headings (e.g., Education, Skills, etc.) and all lowercase letters for job titles and bullet points.
# 2. Include specific numbers and achievements: While John Doe provides brief descriptions of his projects, it would be more effective to quantify his accomplishments with specific numbers whenever possible. For example, instead of writing "Built a predictive model to analyze customer churn for a large retail customer," he could write "Built a predictive model that reduced customer churn by 20% for a large retail customer."
# 3. Optimize the layout for readability: The resume is currently formatted as a single column, which can be hard to read on mobile devices and smaller screens. To make it easier for potential employers to view the resume, consider using a two-column format or optimizing the text size and spacing for smaller screens.
# 4. Use action verbs: John Doe uses action verbs in some bullet points, but it would be helpful to use them consistently throughout the resume. Action verbs can make the resume more dynamic and help the reader quickly understand John Doe's role in each project.
# 5. Include relevant certifications and technical skills: While John Doe mentions his expertise in Python, Machine Learning, and Deep Learning, it would be helpful to include specific certifications or courses he has completed to demonstrate his mastery of these areas. Additionally, he could consider adding other technical skills he has, such as SQL, Java, or R, to make his resume more comprehensive.
#
# Overall, John Doe's resume is well-written and presents his qualifications clearly. With the suggested improvements, it could be even stronger and catch the attention of potential employers in the data science field.
#
# Custom Instruction Feedback: Analyze the resume and provide feedback on formatting. Jane Smith has a background in Software Development, specializing in Java, Cloud Computing, and DevOps. Here's her resume:
#
# ---
#
# **Jane Smith**
# email@example.com | (123) 456-7890 | [LinkedIn Profile](www.linkedin.com/in/janesmith)
#
# **Profile**
#
# Experienced Full Stack Software Developer with a passion for building scalable and secure applications. Proficient in Java, Cloud Computing, and DevOps. Skilled in agile methodologies, collaborative team environments, and continuous integration/deployment (CI/CD).
#
# **Technical Skills**
#
# - Languages: Java, JavaScript, Python, SQL
# - Frameworks: Spring, Hibernate, React, Angular
# - Cloud: AWS, Google Cloud, Docker
# - DevOps: Jenkins, Ansible, Git, Maven, Jenkins Pipelines
# - Database: MySQL, MongoDB, Oracle
# - IDE: IntelliJ IDEA, Eclipse, Visual Studio Code
#
# **Work Experience**
#
# **Software Developer II | XYZ Corp | [Dallas, TX] ([www.xyzcorp.com](http://www.xyzcorp.com)) | March 2018 - Present**
#
# - Designed and developed high-performance web applications in Java and Spring Framework.
# - Implemented RESTful APIs,migrated databases to MongoDB, and integrated Third-Party APIs.
# - Collaborated with cross-functional teams to design, develop, test, and deploy cloud-native applications on AWS.
# - Participated in agile sprints and utilized Jenkins Pipelines for CI/CD.
# - Maintained and refactored legacy codebase to increase reliability and scalability.
#
# **Software Developer I | ABC Corp | [Chicago, IL] ([www.abccorp.com](http://www.abccorp.com)) | June 2016 - February 2018**
#
# - Developed possibly complex systems with Java and AngularJS in an Agile Environment
# - Integrated RESTful APIs,migrated databases to MySQL, and collaborated with DevOps team for deployments
# - Actively participated in Code Reviews, Testing, and Debugging
# - Maintained accurate and concise documentation for current project work and previous work
#
# **Education**
#
# **Master of Computer Science (MCS) | DEF University | [Houston, TX] ([www.defuniversity.edu](http://www.defuniversity.edu)) | August 2014 - May 2016**
#
# **Bachelor of Computer Science (BCS) | GHI University | [Austin, TX] ([www.ghiuniversity.edu](http://www.ghiuniversity.edu)) | August 2010 - May 2014**
#
# **Certifications**
#
# Oracle Certified Professional, Java SE 11 Programmer
#
# **Awards & Honors**
#
# - Magna Cum Laude, GHI University
# - Winner, DEF University Annual Hackathon (2015)
#
# ---
#
# **Feedback:**
#
# 1. **Header:** The header is well-organized and includes all essential contact information. However, it could be more consistent. For example, the phone number format is inconsistent between the header and the contact information below the summary. Consider standardizing the format.
#
# 2. **Profile:** The profile is engaging and well-written. However, it could be more concise. Consider omitting repetitive phrases like "proficient in" and focus on highlighting key skills and accomplishments.
#
# 3. **Technical Skills:** Once again, the format is consistent, and it's easy to quickly see Jane's technical expertise. Consider grouping similar skills (e.g., databases, IDE) and alphabetizing them for easier readability.
#
# 4. **Work Experience:** The work experience section is detailed and well-structured. However, consider using bullet points instead of full sentences for better readability. Also, it would be helpful to include specific achievements, such as cost savings, increased efficiency, or positive user feedback, to quantify the impact of Jane's work.
#
# 5. **Education:** The education section is accurate and includes relevant details. However, it's somewhat lengthy. Consider abbreviating the university names (DEF for DEF University, GHI for GHI University) to save space.
#
# 6. **Certifications:** This section is brief and clear.
#
# 7. **Awards & Honors:** This section is short and showcases Jane's academics and technical prowess.
#
# Overall, Jane's resume is well-written and demonstrates her technical skills effectively. Slight formatting adjustments can help improve readability and make the resume stand out to potential employers.
#
# Custom Instruction Feedback: Analyze the resume and provide feedback on formatting. Mike Johnson is a recent graduate with a passion for Artificial Intelligence and Data Analysis. The resume contains sections for work experience, education, skills, certifications, and projects, as well as a summary statement that highlights Mike's qualifications, relevant skills, and career objective.
#
# **Summary Statement:**
#
# Detail-oriented and highly motivated Artificial Intelligence and Data Analysis enthusiast seeking a challenging position in the technology or financial sector. Possess strong mathematical skills, excellent problem-solving abilities, and proficiency in various programming languages and data analysis tools.
#
# **Education:**
#
# Bachelor of Science in Computer Science
# University of Michigan (2018 - 2022)
# GPA: 3.8/4.0
#
# **Work Experience:**
#
# **Data Analysis Intern** (Summer 2021)
# [XYZ Corporation]
#
# * Collaborated with data team to identify trends and optimize processes for streamlined analysis
# * Conducted data cleaning and pre-processing steps to ensure data quality
# * Utilized Python, Excel, and SQL to perform statistical analysis on various datasets
# * Presented findings to stakeholders in clear and concise fashion
# * Implemented improvements to data collection and reporting procedures
#
# **Teaching Assistant** (Fall 2019 - Spring 2020)
# [University of Michigan]
#
# * Supported professors in classroom instruction for introduction to computer science course
# * Assisted students with assignments and projects related to programming and data analysis concepts
# * Graded assignments, provided feedback, and facilitated discussions on course progress
#
# **Skills:**
#
# - Programming languages: Python, SQL, R, Java
# - Data analysis tools: Excel, PowerBI, Tableau, Jupyter Notebook
# - Machine learning frameworks/libraries: TensorFlow, Scikit-learn, Keras
# - Algorithms: Linear Regression, Decision Trees, Random Forest, Support Vector Machines, Neural Networks
# - Databases: SQL Server, MySQL, PostgreSQL, MongoDB
# - Operating Systems: Windows, macOS, Linux
# - Version control systems: Git, SVN
#
# **Certifications:**
#
# - AWS Certified Big Data - Specialty (2022)
#
# **Projects:**
#
# **1. Stock Prediction Model**
# Built a machine learning model using LSTM neural network to predict stock prices for selected companies based on historical data. Achieved 85% accuracy for short-term predictions and 65% accuracy for long-term predictions.
#
# **2. Fraud Detection System**
# Developed a fraud detection system using ensemble methods and clustering algorithms to detect anomalies in credit card transactions. Implemented the system in Python and utilized TensorFlow and Scikit-learn for model training. Reduced false positive rate by 30% compared to previous system.
#
# In terms of formatting, Mike's resume is well-organized and easy to read. The use of bullet points for work experience and skills makes it easy to quickly scan. The bolding of section headers helps draw the eye. The use of numbers and percentages for accomplishments adds quantifiable value to Mike's experiences. Overall, the formatting is professional and effective in showcasing Mike's qualifications.
#
# One potential improvement for the formatting could be to consider using a reverse-chronological format for work experience, starting with the most recent internship at XYZ Corporation and then listing the Teaching Assistant position afterwards. Additionally, it would be beneficial to add dates for Work Experience section, such as the start and end dates for internships and positions.
#
# For consistency, Mike could also consider using the same font type and size throughout the document, and possibly add more whitespace between sections to make it easier to read.
#
# In terms of content, Mike has done a good job of highlighting relevant skills and accomplishments, as well as providing specific details about his experience and projects. It would be useful for him to consider tailoring his resume to each specific job he applies for, by emphasizing the skills and experiences that are most relevant to that particular position. Additionally, Mike could consider adding any relevant coursework or projects to his Education section to further demonstrate his expertise in Artificial Intelligence and Data Analysis.
#
# Overall, Mike's resume is well-written and effectively highlights his qualifications as a candidate for a position in the technology or financial sector. With a few minor formatting tweaks and some tailoring to each specific job, this resume is sure to impress potential employers.
